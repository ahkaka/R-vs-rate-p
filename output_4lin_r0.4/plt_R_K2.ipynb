# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# 1. 加载数据
file_path = '/Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/scan_R_K1.csv'
df = pd.read_csv(file_path, index_col=0)
df.columns = df.columns.astype(float)

# 2. 输出路径（请修改为你的保存位置）
save_dir = '/Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1'
os.makedirs(save_dir, exist_ok=True)

# 3. 循环所有 p_index
for p_index in range(20):   # 0 到 19
    # 提取一列
    R_vs_rate = df.iloc[:, p_index]
    actual_p_value = df.columns[p_index]  # 对应的 p_s 值

    # --- 绘图开始 ---
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

    # 左图：线性横坐标
    R_vs_rate.plot(ax=ax1, marker='o', linestyle='-', color='blue')
    ax1.set_xlabel('$r_1$ (Rate Scale)')
    ax1.set_ylabel('$R$')
    ax1.set_title(f'Linear X-axis\n$p_s$={actual_p_value:.3f}')
    ax1.grid(True, linestyle='--')
    ax1.set_ylim(-0.05,1)

    # 右图：log 横坐标
    R_vs_rate.plot(ax=ax2, marker='o', linestyle='-', color='blue')
    ax2.set_xscale('log')
    ax2.set_xlabel('$r_1$ (Rate Scale)')
    ax2.set_title(f'Log X-axis\n$p_s$={actual_p_value:.3f}')
    ax2.grid(True, linestyle='--')
    ax2.set_ylim(-0.05,1)

    plt.tight_layout()

    # 生成保存路径
    save_path = os.path.join(save_dir, f'P_{p_index}_ps_{actual_p_value:.3f}.png')

    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"已保存: {save_path}")
# Out:
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_0_ps_0.300.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_1_ps_0.334.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_2_ps_0.368.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_3_ps_0.403.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_4_ps_0.437.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_5_ps_0.471.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_6_ps_0.505.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_7_ps_0.539.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_8_ps_0.574.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_9_ps_0.608.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_10_ps_0.642.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_11_ps_0.676.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_12_ps_0.711.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_13_ps_0.745.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_14_ps_0.779.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_15_ps_0.813.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_16_ps_0.847.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_17_ps_0.882.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_18_ps_0.916.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/p_index_K1/P_19_ps_0.950.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# 1. 加载数据
file_path = '/Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/scan_R_K1.csv'
df = pd.read_csv(file_path, index_col=0)

# 保证 p_s 列名为浮点数（横轴需要）
df.columns = df.columns.astype(float)

# 2. 输出路径（请改成你的路径）
save_dir = '/Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1'
os.makedirs(save_dir, exist_ok=True)

# 3. 循环每个 rate 对应的一行（0 到 19）
for r_index in range(20):

    # 取出一行
    row_series = df.iloc[r_index, :]
    r_value = df.index[r_index]    # r₁ 的真实数值，用于文件名/标题

    # --- 绘图 ---
    plt.figure(figsize=(7, 5))

    # 横轴 = p 值；纵轴 = R
    plt.plot(df.columns, row_series.values,
             marker='o', linestyle='-', color='blue')

    plt.xlabel('$p_s$')
    plt.ylabel('$R$')
    plt.title(f'R vs p_s  (r₁ = {r_value:.6f})')
    plt.grid(True, linestyle='--')
    plt.ylim(-0.05,1)
    # 保存
    save_path = os.path.join(save_dir, f"r_{r_index}_rvalue_{r_value:.3f}.png")
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"已保存: {save_path}")
# Out:
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_0_rvalue_0.000.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_1_rvalue_0.021.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_2_rvalue_0.042.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_3_rvalue_0.063.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_4_rvalue_0.084.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_5_rvalue_0.105.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_6_rvalue_0.126.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_7_rvalue_0.147.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_8_rvalue_0.168.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_9_rvalue_0.189.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_10_rvalue_0.211.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_11_rvalue_0.232.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_12_rvalue_0.253.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_13_rvalue_0.274.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_14_rvalue_0.295.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_15_rvalue_0.316.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_16_rvalue_0.337.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_17_rvalue_0.358.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_18_rvalue_0.379.png
# 已保存: /Users/xiroihs/Documents/序参量随速率与比例/output_4lin_r0.4/r_index_K1/r_19_rvalue_0.400.png
